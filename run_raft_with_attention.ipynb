# %%
# !python src/main.py --name raft-attention --loss L1-loss --iters 12 --epochs 305 --checkpoints 300
# Out:
# Model Summary:
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 32, 192, 256]           4,736
#     InstanceNorm2d-2         [-1, 32, 192, 256]               0
#               ReLU-3         [-1, 32, 192, 256]               0
#             Conv2d-4          [-1, 8, 192, 256]             264
#     InstanceNorm2d-5          [-1, 8, 192, 256]               0
#               ReLU-6          [-1, 8, 192, 256]               0
#             Conv2d-7          [-1, 8, 192, 256]             584
#     InstanceNorm2d-8          [-1, 8, 192, 256]               0
#               ReLU-9          [-1, 8, 192, 256]               0
#            Conv2d-10         [-1, 32, 192, 256]             288
#    InstanceNorm2d-11         [-1, 32, 192, 256]               0
#              ReLU-12         [-1, 32, 192, 256]               0
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

path = f'./train_raft-attention/images/flow300_0.png'
image = plt.imread(path)
plt.imshow(image)
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
import numpy as np

path = f'./train_raft-attention/images/flow300_1.png'
image = plt.imread(path)
plt.imshow(image)

# %%
import matplotlib.pyplot as plt
import numpy as np

path = f'./train_raft-attention/images/flow300_2.png'
image = plt.imread(path)
plt.imshow(image)

# %%
import matplotlib.pyplot as plt
import numpy as np

path = f'./train_raft-attention/images/flow300_3.png'
image = plt.imread(path)
plt.imshow(image)
